# %%
import multiprocessing as mp
def tarea(cadena):
    print('Hola',cadena)
    
    
    
if __name__=='__main__':  
    p=mp.Process(target= tarea,args=('Lucas C. ',))
    p.start() 
    p.join()
# Out:
# Hola Lucas C.

# %%
import multiprocessing as mp

def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

nums= range(10)
p1 = mp.Process(target=calc_cuad,args=(nums,))
p1.start()
p1.join()


print('Temrina la ejecución numérica')
# Out:
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# cuadrado: 9
# cuadrado: 16
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# Temrina la ejecución numérica

# %% [markdown]
# ## Ejercicio: Crea otro proceso P2 para calcular el cubo del mismo conjunto de números nums y mándalos a imprimir

# %%
import multiprocessing as mp
def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(10)
p2 = mp.Process(target=calc_cubo,args=(nums,))
p2.start()
p2.join()
# Out:
# Calcula el cubo de los numeros
# cubo: 0
# cubo: 1
# cubo: 8
# cubo: 27
# cubo: 64
# cubo: 125
# cubo: 216
# cubo: 343
# cubo: 512
# cubo: 729

# %% [markdown]
# ##Ejercicio: Realizar el código que muestre los cuadrados y los cubos.

# %%
import multiprocessing as mp
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(10)
p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p1.start()
p1.join()
p2.start()
p2.join()

print('Termina la ejecución :)')
# Out:
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# cuadrado: 9
# cuadrado: 16
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# Calcula el cubo de los numeros
# cubo: 0
# cubo: 1
# cubo: 8
# cubo: 27
# cubo: 64
# cubo: 125
# cubo: 216
# cubo: 343
# cubo: 512
# cubo: 729
# Termina la ejecución :)

# %% [markdown]
# ##Ejercicio:
# 1. Calcula el cuadrado y el cubo de un arreglo de tamaño 100 de manera secuencial con funciones y calcula su tiempo de ejecución con time.time().
# 2. Calcula el cuadrado y el cubo usando procesos y calcula el tiempo de ejecución.
# 3. Calcula el cuadrado y el cubo usando procesos y varía el start y el join de los procesos, calcula el tiempo de ejecución.

# %%
import multiprocessing as mp
import time
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(100)
t = time.time()

p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p1.start()
p1.join()
p2.start()
p2.join()
print('Tiempo de ejecución', time.time()-t)
print('Termina la ejecución :)')
# Out:
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# cuadrado: 9
# cuadrado: 16
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# cuadrado: 100
# cuadrado: 121
# cuadrado: 144
# cuadrado: 169
# cuadrado: 196
# cuadrado: 225
# cuadrado: 256
# cuadrado: 289
# cuadrado: 324
# cuadrado: 361
# cuadrado: 400
# cuadrado: 441
# cuadrado: 484
# cuadrado: 529
# cuadrado: 576
# cuadrado: 625
# cuadrado: 676
# cuadrado: 729
# cuadrado: 784
# cuadrado: 841
# cuadrado: 900
# cuadrado: 961
# cuadrado: 1024
# cuadrado: 1089
# cuadrado: 1156
# cuadrado: 1225
# cuadrado: 1296
# cuadrado: 1369
# cuadrado: 1444
# cuadrado: 1521
# cuadrado: 1600
# cuadrado: 1681
# cuadrado: 1764
# cuadrado: 1849
# cuadrado: 1936
# cuadrado: 2025
# cuadrado: 2116
# cuadrado: 2209
# cuadrado: 2304
# cuadrado: 2401
# cuadrado: 2500
# cuadrado: 2601
# cuadrado: 2704
# cuadrado: 2809
# cuadrado: 2916
# cuadrado: 3025
# cuadrado: 3136
# cuadrado: 3249
# cuadrado: 3364
# ...

# %%
import multiprocessing as mp
import time
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(100)
t = time.time()

p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p1.start()
p1.join()
print('Tiempo de ejecución', time.time()-t)
p2.start()
p2.join()
print('Tiempo de ejecución', time.time()-t)
print('Termina la ejecución :)')
# Out:
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# cuadrado: 9
# cuadrado: 16
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# cuadrado: 100
# cuadrado: 121
# cuadrado: 144
# cuadrado: 169
# cuadrado: 196
# cuadrado: 225
# cuadrado: 256
# cuadrado: 289
# cuadrado: 324
# cuadrado: 361
# cuadrado: 400
# cuadrado: 441
# cuadrado: 484
# cuadrado: 529
# cuadrado: 576
# cuadrado: 625
# cuadrado: 676
# cuadrado: 729
# cuadrado: 784
# cuadrado: 841
# cuadrado: 900
# cuadrado: 961
# cuadrado: 1024
# cuadrado: 1089
# cuadrado: 1156
# cuadrado: 1225
# cuadrado: 1296
# cuadrado: 1369
# cuadrado: 1444
# cuadrado: 1521
# cuadrado: 1600
# cuadrado: 1681
# cuadrado: 1764
# cuadrado: 1849
# cuadrado: 1936
# cuadrado: 2025
# cuadrado: 2116
# cuadrado: 2209
# cuadrado: 2304
# cuadrado: 2401
# cuadrado: 2500
# cuadrado: 2601
# cuadrado: 2704
# cuadrado: 2809
# cuadrado: 2916
# cuadrado: 3025
# cuadrado: 3136
# cuadrado: 3249
# cuadrado: 3364
# ...

# %%
import multiprocessing as mp
import time
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(100)
t = time.time()

p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p1.start()
p2.start()
p1.join()
p2.join()
print('Tiempo de ejecución', time.time()-t)
print('Termina la ejecución :)')
# Out:
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cuadrado: 1
# cuadrado: 4
# Calcula el cubo de los numeros
# cubo: 0
# cuadrado: 9
# cubo: 1
# cuadrado: 16
# cuadrado: 25
# cubo: 8
# cuadrado: 36
# cubo: 27
# cubo: 64
# cuadrado: 49
# cubo: 125
# cubo: 216
# cubo: 343
# cuadrado: 64
# cuadrado: 81
# cubo: 512
# cuadrado: 100
# cubo: 729
# cubo: 1000
# cuadrado: 121
# cuadrado: 144
# cubo: 1331
# cuadrado: 169
# cubo: 1728
# cubo: 2197
# cuadrado: 196
# cubo: 2744
# cuadrado: 225
# cuadrado: 256
# cuadrado: 289
# cubo: 3375
# cubo: 4096
# cuadrado: 324
# cubo: 4913
# cuadrado: 361
# cuadrado: 400
# cuadrado: 441
# cubo: 5832
# cuadrado: 484
# cuadrado: 529
# cubo: 6859
# cuadrado: 576
# cuadrado: 625
# cubo: 8000
# cuadrado: 676
# cubo: 9261
# cuadrado: 729
# cubo: 10648
# cuadrado: 784
# cuadrado: 841
# cubo: 12167
# cuadrado: 900
# cubo: 13824
# cuadrado: 961
# cuadrado: 1024
# cuadrado: 1089
# cubo: 15625
# cuadrado: 1156
# cubo: 17576
# cubo: 19683
# cuadrado: 1225
# ...

# %%
import multiprocessing as mp
import time
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(100)
t = time.time()

p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p2.start()
p1.start()
p1.join()
p2.join()
print('Tiempo de ejecución', time.time()-t)
print('Termina la ejecución :)')
# Out:
# Calcula el cubo de los numeros
# Calcula el cuadrado de los numeros
# cubo: 0
# cuadrado: 0
# cuadrado: 1
# cubo: 1
# cubo: 8
# cuadrado: 4
# cubo: 27
# cuadrado: 9
# cubo: 64
# cuadrado: 16
# cuadrado: 25
# cubo: 125
# cubo: 216
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cubo: 343
# cubo: 512
# cubo: 729
# cuadrado: 81
# cuadrado: 100
# cubo: 1000
# cubo: 1331
# cuadrado: 121
# cubo: 1728
# cubo: 2197
# cubo: 2744
# cubo: 3375
# cubo: 4096
# cuadrado: 144
# cuadrado: 169
# cubo: 4913
# cuadrado: 196
# cubo: 5832
# cubo: 6859
# cubo: 8000
# cubo: 9261
# cubo: 10648
# cubo: 12167
# cuadrado: 225
# cuadrado: 256
# cuadrado: 289
# cuadrado: 324
# cubo: 13824
# cuadrado: 361
# cuadrado: 400
# cuadrado: 441
# cuadrado: 484
# cuadrado: 529
# cuadrado: 576
# cuadrado: 625
# cubo: 15625
# cuadrado: 676
# cuadrado: 729
# cubo: 17576
# cuadrado: 784
# cuadrado: 841
# cuadrado: 900
# cuadrado: 961
# cuadrado: 1024
# cuadrado: 1089
# cuadrado: 1156
# cuadrado: 1225
# cuadrado: 1296
# ...

# %%
import multiprocessing as mp
import time
def calc_cuad(numeros):
    print('Calcula el cuadrado de los numeros')
    for n in numeros:
        print('cuadrado:', n*n)

def calc_cubo(numeros):
    print('Calcula el cubo de los numeros')
    for n in numeros:
        print('cubo:', n*n*n)

nums= range(100)
t = time.time()

p1 = mp.Process(target=calc_cuad,args=(nums,))
p2 = mp.Process(target=calc_cubo,args=(nums,))
p2.start()
p1.start()
p2.join()
p1.join()

print('Tiempo de ejecución', time.time()-t)
print('Termina la ejecución :)')
# Out:
# Calcula el cubo de los numeros
# cubo: 0
# cubo: 1
# cubo: 8
# cubo: 27
# cubo: 64
# Calcula el cuadrado de los numeros
# cuadrado: 0
# cubo: 125
# cubo: 216
# cuadrado: 1
# cuadrado: 4
# cubo: 343
# cubo: 512
# cubo: 729
# cubo: 1000
# cubo: 1331
# cubo: 1728
# cubo: 2197
# cubo: 2744
# cubo: 3375
# cubo: 4096
# cubo: 4913
# cubo: 5832
# cubo: 6859
# cubo: 8000
# cubo: 10648
# cubo: 9261
# cubo: 12167
# cubo: 13824
# cuadrado: 9
# cubo: 15625
# cuadrado: 16
# cubo: 17576
# cuadrado: 25
# cuadrado: 36
# cuadrado: 49
# cuadrado: 64
# cuadrado: 81
# cuadrado: 100
# cuadrado: 121
# cuadrado: 144
# cubo: 19683
# cuadrado: 169
# cubo: 21952
# cubo: 24389
# cuadrado: 196
# cubo: 27000
# cubo: 29791
# cubo: 32768
# cubo: 35937
# cubo: 39304
# cubo: 42875
# cubo: 46656
# cuadrado: 225
# cuadrado: 256
# cubo: 50653
# cubo: 54872
# cubo: 59319
# cuadrado: 289
# cuadrado: 324
# cubo: 64000
# cubo: 68921
# cubo: 74088
# cubo: 79507
# cuadrado: 361
# cuadrado: 400
# cubo: 85184
# cuadrado: 441
# ...
